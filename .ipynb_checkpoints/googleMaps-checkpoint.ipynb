# %%
import googlemaps
import os

API_KEY = "AIzaSyDYfKFPlsmMRCFDxR-nVEN2uMckW393DZQ"
gmaps = googlemaps.Client(key=API_KEY)
print(gmaps.geocode("Nairobi"))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 5
#       2 import os
#       4 API_KEY = "AIzaSyDYfKFPlsmMRCFDxR-nVEN2uMckW393DZQ"
# ----> 5 gmaps = googlemaps.Client(key=os.environ["API_KEY"])
#       6 print(gmaps.geocode("Nairobi"))
#
# File <frozen os>:714, in __getitem__(self, key)
#
# KeyError: 'API_KEY'

# %%
# !pip3 install googlemaps
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for googlemaps: filename=googlemaps-4.10.0-py3-none-any.whl size=40714 sha256=076afb7f5dfe9e166e36804e5651041cde9c7588135dfc0f1ef3d736abad0b4a
#   Stored in directory: /home/lambda86/snap/jupyterlab-desktop/common/.cache/pip/wheels/4c/6a/a7/bbc6f5c200032025ee655deb5e163ce8594fa05e67d973aad6
# Successfully built googlemaps
# ...
